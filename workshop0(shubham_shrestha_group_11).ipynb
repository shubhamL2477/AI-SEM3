# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamL2477/AI-SEM3/blob/main/workshop0(shubham_shrestha_group_11).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TIME DATA / TASK 1

# %%
time_data = [
(3.5,2,7),(5,1.5,6.5),(2.5,3,8),
(4,2,6),(1.5,4.5,9),(3,2.5,7.5),
(5.5,1,6),(2,3.5,8.5),(4.5,2,7),
(3,3,7.5),(6,1.5,6),(2.5,4,8),
(4,2.5,7),(5,2,6.5),(3.5,2.5,7)
]


low = []
moderate = []
high = []

for s, e, sl in time_data:
    if s < 3: low.append(s)
    elif s <= 5: moderate.append(s)
    else: high.append(s)

print(low)
print(moderate)
print(high)
# Out:
# [2.5, 1.5, 2, 2.5]
# [3.5, 5, 4, 3, 4.5, 3, 4, 5, 3.5]
# [5.5, 6]

# %% [markdown]
# TASK 2

# %%
print(len(low))
print(len(moderate))
print(len(high))
# Out:
# 4
# 9
# 2

# %% [markdown]
# TASK 3

# %%
study_minutes = [s*60 for s,_,_ in time_data]
print(study_minutes)
# Out:
# [210.0, 300, 150.0, 240, 90.0, 180, 330.0, 120, 270.0, 180, 360, 150.0, 240, 300, 210.0]

# %% [markdown]
# TASK 4

# %%
study = [s for s,_,_ in time_data]
ent = [e for _,e,_ in time_data]
sleep = [sl for *_,sl in time_data]

print("avg time for Studing: ",sum(study)/len(study))
print("avg time for Entertainment: ",sum(ent)/len(ent))
print("avg time for Sleeping: ",sum(sleep)/len(sleep))
# Out:
# avg time for Studing:  3.7
# avg time for Entertainment:  2.5
# avg time for Sleeping:  7.166666666666667

# %% [markdown]
# TASK 5

# %%
import matplotlib.pyplot as plt

plt.scatter(study, sleep)
plt.title("Sleep vs Study")
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.show()

# %% [markdown]
#   TASK 1/ NESTED_LIST

# %%
def sum_nested_list(nested_list):
    total = 0
    for item in nested_list:
        if isinstance(item, list):
            total += sum_nested_list(item)
        else:
            total += item
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]

result = sum_nested_list(nested_list)

print("Sum =", result)
# Out:
# Sum = 36

# %% [markdown]
# TASK 2

# %%
def generate_permutations(s):
    if len(s) == 0:
        return [""]

    perms = []
    for i in range(len(s)):
        ch = s[i]
        remaining = s[:i] + s[i+1:]

        for p in generate_permutations(remaining):
            perms.append(ch + p)


    return list(dict.fromkeys(perms))

print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %% [markdown]
# TASK 3

# %%
def calculate_directory_size(directory):
    total = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total += calculate_directory_size(value)
        else:
            total += value
    return total

directory_structure = {
 "file1.txt": 200,
 "file2.txt": 300,
 "subdir1": {"file3.txt": 400, "file4.txt": 100},
 "subdir2": {"subsubdir1": {"file5.txt": 250}, "file6.txt": 150}
}

print(calculate_directory_size(directory_structure))
# Out:
# 1400

# %% [markdown]
# TASK 1

# %%
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0
    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    return dp[amount] if dp[amount] != float('inf') else -1

print(min_coins([1,2,5], 11))
# Out:
# 3

# %% [markdown]
# TASK 2

# %%
def longest_common_subsequence(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0]*(m+1) for _ in range(n+1)]
    for i in range(1, n+1):
        for j in range(1, m+1):
            if s1[i-1] == s2[j-1]:
                dp[i][j] = dp[i-1][j-1] + 1
            else:
                dp[i][j] = max(dp[i-1][j], dp[i][j-1])
    return dp[n][m]

print(longest_common_subsequence("abcde", "ace"))

# %% [markdown]
# TASK 3

# %%
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n+1)]
    for i in range(1, n+1):
        wt = weights[i-1]
        val = values[i-1]
        for w in range(capacity + 1):
            dp[i][w] = dp[i-1][w]  # not take
            if wt <= w:
                dp[i][w] = max(dp[i][w], dp[i-1][w-wt] + val)
    return dp[n][capacity]

print(knapsack([1,3,4,5], [1,4,5,7], 7))
